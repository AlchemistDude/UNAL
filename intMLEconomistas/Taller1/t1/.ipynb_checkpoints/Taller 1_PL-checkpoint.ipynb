# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # ENGLISH PREMIER LEAGUE 2017/2018

# %% [markdown]
# ![i.png](attachment:98dbe087-6f4c-4147-b426-326a2a0ec304.png)

# %%
df = pd.read_csv("data.csv")

# %%
df.columns
# Out:
# Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')

# %% [markdown]
# This dataset was taken from Kaggle site and it is composed as follows:
#
# - name: Name of the player.
# - club: Club of the player.
# - age: Age of the player.
# - position: The usual position on the pitch.
# - position_cat: 1 for attackers, 2 for midfielders, 3 for defenders, 4 for goalkeepers.
# - market_value : As on transfermrkt.com on July 20th, 2017.
# - page_views : Average daily Wikipedia page views from September 1, 2016 to May 1, 2017.
# - fpl_value : Value in Fantasy Premier League as on July 20th, 2017.
# - fpl_sel : % of FPL players who have selected that player in their team.
# - fpl_points : FPL points accumulated over the previous season.
# - region: 1 for England, 2 for EU, 3 for Americas and 4 for Rest of the World.
# - nationality: origin country.
# - new_foreign : Whether a new signing from a different league, for 2017/18 (till 20th July).
# - age_cat: age category.
# - club_id
# - big_club: Whether one of the Top 6 clubs.
# - new_signing: Whether a new signing for 2017/18 (till 20th July).
#
# This data is from 2017.

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
df.shape
# Out:
# (461, 17)

# %% [markdown]
# We have 461 rows and 17 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461 entries, 0 to 460
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          461 non-null    object
#  1   club          461 non-null    object
#  2   age           461 non-null    int64
#  3   position      461 non-null    object
#  4   position_cat  461 non-null    int64
#  5   market_value  461 non-null    float64
#  6   page_views    461 non-null    int64
#  7   fpl_value     461 non-null    float64
#  8   fpl_sel       461 non-null    object
#  9   fpl_points    461 non-null    int64
#  10  region        460 non-null    float64
#  11  nationality   461 non-null    object
#  12  new_foreign   461 non-null    int64
#  13  age_cat       461 non-null    int64
#  14  club_id       461 non-null    int64
#  15  big_club      461 non-null    int64
#  16  new_signing   461 non-null    int64
# dtypes: float64(3), int64(9), object(5)
# ...

# %%
df.fpl_sel
# Out:
# 0      17.10%
# 1       5.60%
# 2       5.90%
# 3       1.50%
# 4       0.70%
#         ...
# 456     0.40%
# 457     0.20%
# 458     0.30%
# 459     5.90%
# 460     0.10%
# Name: fpl_sel, Length: 461, dtype: object

# %% [markdown]
# Looking at the fpl_sel column and in info, we know that fpl_sel is a percentage so it must be float but in the dataframe it is object type, so we will convert it.

# %%
df['fpl_sel'] = df['fpl_sel'].str.replace("%","")
df['fpl_sel'] = df['fpl_sel'].astype(float)

# %%
df.fpl_sel
# Out:
# 0      17.1
# 1       5.6
# 2       5.9
# 3       1.5
# 4       0.7
#        ...
# 456     0.4
# 457     0.2
# 458     0.3
# 459     5.9
# 460     0.1
# Name: fpl_sel, Length: 461, dtype: float64

# %%
df.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value  fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0     17.1         264     3.0           Chile
# 1        4395        9.5      5.6         167     2.0         Germany
# 2        1529        5.5      5.9         134     2.0  Czech Republic
# 3        2393        7.5      1.5         122     1.0         England
# 4         912        6.0      0.7         121     2.0          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %%
df.tail()
# Out:
#                     name      club  age position  position_cat  market_value  \
# 456  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 457       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 458            Sam Byram  West+Ham   23       RB             3           4.5
# 459      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 460         Diafra Sakho  West+Ham   27       CF             1          10.0
#
#      page_views  fpl_value  fpl_sel  fpl_points  region  nationality  \
# 456         288        4.5      0.4          38     2.0  Switzerland
# 457         199        4.5      0.2          34     4.0     Congo DR
# 458         198        4.5      0.3          29     1.0      England
# 459         412        4.5      5.9          16     1.0      England
# 460         214        5.5      0.1          12     4.0      Senegal
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %% [markdown]
# Basic statistics about the dataframe

# %%
df.describe()
# Out:
#               age  position_cat  market_value   page_views   fpl_value  \
# count  461.000000    461.000000    461.000000   461.000000  461.000000
# mean    26.804772      2.180043     11.012039   763.776573    5.447939
# std      3.961892      1.000061     12.257403   931.805757    1.346695
# min     17.000000      1.000000      0.050000     3.000000    4.000000
# 25%     24.000000      1.000000      3.000000   220.000000    4.500000
# 50%     27.000000      2.000000      7.000000   460.000000    5.000000
# 75%     30.000000      3.000000     15.000000   896.000000    5.500000
# max     38.000000      4.000000     75.000000  7664.000000   12.500000
#
#           fpl_sel  fpl_points      region  new_foreign     age_cat  \
# count  461.000000  461.000000  460.000000   461.000000  461.000000
# mean     3.244252   57.314534    1.993478     0.034707    3.206074
# std      5.675657   53.113811    0.957689     0.183236    1.279795
# ...

# %% [markdown]
# Let's see if there is missing data:

# %%
df.isnull().sum()
# Out:
# name            0
# club            0
# age             0
# position        0
# position_cat    0
# market_value    0
# page_views      0
# fpl_value       0
# fpl_sel         0
# fpl_points      0
# region          1
# nationality     0
# new_foreign     0
# age_cat         0
# club_id         0
# big_club        0
# new_signing     0
# dtype: int64

# %% [markdown]
# It looks like there is only one empty register at column region, lets look at it:

# %%
df.region[pd.isna(df['region'])]
# Out:
# 188   NaN
# Name: region, dtype: float64

# %%
df.iloc[188]
# Out:
# name            Steve Mounie
# club            Huddersfield
# age                       22
# position                  CF
# position_cat               1
# market_value             5.5
# page_views                56
# fpl_value                6.0
# fpl_sel                  0.6
# fpl_points                 0
# region                   NaN
# nationality            Benin
# new_foreign                0
# age_cat                    2
# club_id                    8
# big_club                   0
# new_signing                0
# Name: 188, dtype: object

# %% [markdown]
# With a fast search at google we can see that Benin country is from Africa, so we can put it manually.

# %%
df['region'] = df['region'].replace(['NaN'],4)

# %%
df.loc[188,'region'] = 4

# %% [markdown]
# Lets check it again:

# %%
df.isnull().sum()
# Out:
# name            0
# club            0
# age             0
# position        0
# position_cat    0
# market_value    0
# page_views      0
# fpl_value       0
# fpl_sel         0
# fpl_points      0
# region          0
# nationality     0
# new_foreign     0
# age_cat         0
# club_id         0
# big_club        0
# new_signing     0
# dtype: int64

# %% [markdown]
# Lets look for duplicates:

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The are no duplicates.

# %% [markdown]
# We can continue on our EDA.

# %% [markdown]
# Let's look for the top 5 most expensive players:

# %%
df.sort_values(by=['market_value'],ascending=False).head()
# Out:
#                 name               club  age position  position_cat  \
# 92       Eden Hazard            Chelsea   26       LW             1
# 263       Paul Pogba  Manchester+United   24       CM             2
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 240  Kevin De Bruyne    Manchester+City   26       AM             1
# 241    Sergio Aguero    Manchester+City   29       CF             1
#
#      market_value  page_views  fpl_value  fpl_sel  fpl_points  region  \
# 92           75.0        4220       10.5      2.3         224     2.0
# 263          75.0        7435        8.0     19.5         115     2.0
# 0            65.0        4329       12.0     17.1         264     3.0
# 240          65.0        2252       10.0     17.5         199     2.0
# 241          65.0        4046       11.5      9.7         175     3.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %% [markdown]
# Let's look for the top 5 most popular players:

# %%
df.sort_values(by=['page_views'],ascending=False).head()
# Out:
#              name               club  age position  position_cat  \
# 143  Wayne Rooney            Everton   31       SS             1
# 263    Paul Pogba  Manchester+United   24       CM             2
# 376     Dele Alli          Tottenham   21       CM             2
# 93    Diego Costa            Chelsea   28       CF             1
# 1      Mesut Ozil            Arsenal   28       AM             1
#
#      market_value  page_views  fpl_value  fpl_sel  fpl_points  region  \
# 143          15.0        7664        7.5     20.9          76     1.0
# 263          75.0        7435        8.0     19.5         115     2.0
# 376          45.0        4626        9.5     38.6         225     1.0
# 93           50.0        4454       10.0      3.0         196     2.0
# 1            50.0        4395        9.5      5.6         167     2.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 143     England            0        4        7         0            0
# ...

# %%
sns.countplot(data=df.sort_values(by=['page_views'],ascending=False).head(),x="club")
plt.xticks(rotation=45)
plt.title("Top 5 most popular players clubs")
plt.show()

# %% [markdown]
# Now let's look for the top 5 most valuable players in Fantasy Premier League:

# %%
df.sort_values(by=['fpl_value'],ascending=False).head()
# Out:
#                name               club  age position  position_cat  \
# 377      Harry Kane          Tottenham   23       CF             1
# 0    Alexis Sanchez            Arsenal   28       LW             1
# 260   Romelu Lukaku  Manchester+United   24       CF             1
# 241   Sergio Aguero    Manchester+City   29       CF             1
# 251   Gabriel Jesus    Manchester+City   20       CF             1
#
#      market_value  page_views  fpl_value  fpl_sel  fpl_points  region  \
# 377          60.0        4161       12.5     35.1         224     1.0
# 0            65.0        4329       12.0     17.1         264     3.0
# 260          50.0        3727       11.5     45.0         221     2.0
# 241          65.0        4046       11.5      9.7         175     3.0
# 251          30.0        4254       10.5     15.2          67     3.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 377     England            0        2       17         1            0
# ...

# %%
sns.countplot(data=df.sort_values(by=['fpl_value'],ascending=False).head(),x="club")
plt.title("Top 5 most valuabe players in FPL by clubs")
# Out:
# Text(0.5, 1.0, 'Top 5 most valuabe players in FPL by clubs')

# %% [markdown]
# Now let's look for the clubs who have the most expensive players:

# %%
df.groupby(['club']).sum().sort_values(by="market_value",ascending=False).head()
# Out:
#                    age  position_cat  market_value  page_views  fpl_value  \
# club
# Manchester+City    540            41        564.00       29487      137.0
# Chelsea            541            45        553.55       35476      130.5
# Arsenal            747            64        550.00       39278      176.5
# Manchester+United  639            60        514.10       45384      149.0
# Tottenham          513            44        460.00       24279      129.0
#
#                    fpl_sel  fpl_points  region  new_foreign  age_cat  club_id  \
# club
# Manchester+City      107.0        1639    47.0            2       65      220
# Chelsea              134.9        2038    45.0            2       67      100
# Arsenal              110.3        1930    56.0            2       90       28
# Manchester+United    154.6        1765    49.0            1       69      300
# Tottenham            151.3        1910    39.0            0       56      340
#
# ...

# %% [markdown]
# These clubs are considered big clubs or the best teams in the PL.

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=df,x='age' )
plt.title("Age probability distribution")
plt.show()

# %% [markdown]
# The age is normally distributed.

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=df,x='page_views' )
plt.title("Wikipedia page views distribution")
plt.show()

# %% [markdown]
# We can see a positive skewness or right skewed distribution for the page views on Wikipedia.

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=df,x='market_value' )
plt.title("Market value distribution")
plt.xlabel("Players market value in Euros millions")
plt.show()

# %% [markdown]
# We can see a positive skewness or right skewed distribution for the market value.

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=df,x='fpl_value' )
plt.title("Fantasy Premier League value distribution")
plt.show()

# %% [markdown]
# We can see a positive skewness or right skewed distribution for FPL value.

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=df,x='fpl_points' )
plt.title("Fantasy Premier League points distribution")
plt.show()

# %% [markdown]
# We can see a positive skewness or right skewed distribution for fpl points.

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df,x="position")
plt.title("Players by position")
plt.show()

# %% [markdown]
# Most PL players are CB or central back defenders, center foreward or center middle.

# %%
plt.figure(figsize=(16,16))
sns.countplot(data=df,y="nationality")
plt.title("Players by nationality")
plt.show()

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df,x="position_cat")
plt.title("Players by position category")
plt.show()

# %% [markdown]
# As we see previously most players are attacker or defenders.

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df,x="region")
plt.title("Players by region")
plt.show()

# %% [markdown]
# Most PL players are from Europe of from England.

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df,x="new_foreign")
plt.title("New foreign players")
plt.show()

# %% [markdown]
# There are few foreign new players this season.

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df,x="new_foreign",hue="big_club")
plt.title("New foreign players by big clubs")
plt.show()

# %% [markdown]
# As we can see all the new foreign players were signed by the big clubs.Later we will see which clubs.

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df,x="club",hue="position_cat")
plt.title("Positions by club")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# At 2017 most PL teams have many defenders and attackers.

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df,x="club",hue="region")
plt.title("Regions by club")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# As we saw before the majoriy of the PL players are from Europe and England

# %%
plt.figure(figsize=(13,7))
sns.stripplot(data=df,x="club",y="market_value",dodge=True)
plt.xticks(rotation=45)
plt.title("players market values by club")
plt.show()

# %% [markdown]
# As expected the most expensive players are from the biggest clubs: Arsenal,Chelsea, Liverpool, Manchester City,Tottenham

# %%
plt.figure(figsize=(16,7))
sns.countplot(data=df,x="age")
plt.title("Players age")
plt.show()

# %% [markdown]
# The majority of the PL players are around 26-28 years old.

# %%
plt.figure(figsize=(13,6))
sns.violinplot(data=df,x="club",y="age",split=True,dodge=True)
plt.xticks(rotation=45)
plt.title("Player ages by club")
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.swarmplot(data=df,x="club",y="age",dodge=True)
plt.xticks(rotation=45)
plt.title("players ages by club")
plt.show()
# Out:
# /home/alchemistdude/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# We can see that the player ages from each club are somehow balanced, Liverpool has the youngest players, other clubs such as Bounermouth, Crystal Palace and West Brom have the oldest players.

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df,x="new_signing",hue="big_club")
plt.title("New players in the PL")
plt.show()

# %%
df[df['new_signing']==1].name.count()
# Out:
# 67

# %% [markdown]
# We can see that 67 is the number of the new players in the PL

# %%
df[df['new_signing']==1][df['big_club']==1].name.count()
# Out:
# /tmp/ipykernel_47632/3416989887.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['new_signing']==1][df['big_club']==1].name.count()
# 23

# %% [markdown]
# From that 67 new players, 23 were signed by the biggest clubs.

# %%
plt.figure(figsize=(13,6))
sns.boxplot(data=df,x="club",y="market_value",hue="new_foreign",dodge=True)
plt.xticks(rotation=45)
plt.title("Players from other leagues signed this season")
plt.show()

# %% [markdown]
# Arsenal, Everton, Chelsea, Manchester city and Watford were the only clubs that signed players from other leagues.

# %%
sns.jointplot(data=df,x="market_value",y="fpl_value",marginal_ticks=True,
              marginal_kws=dict(bins=25,fill=False,multiple="dodge" ))
plt.show()

# %% [markdown]
# As we can see Fantasy premier League value and market place value are highly correlated.

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=df,x="page_views",y="fpl_value",hue="region",size='market_value',alpha=0.5,palette=['red','blue','green','yellow'])
plt.legend(loc='center',bbox_to_anchor=(1.1,0.5))
plt.title("Page views on Wikipedia vs FPL value")
plt.show()

# %% [markdown]
# The PL player with most page views on wikipedia is from England, the player with the highest fpl value is from England too, also with this plot we can see a positive correlation between page views ad fpl value.

# %%
plt.figure(figsize=(15,6))
sns.relplot(data=df,x="page_views",y="fpl_value",hue="region",col='big_club',size='market_value',alpha=0.5,palette=['red','blue','green','yellow'])
plt.legend(loc='center',bbox_to_anchor=(1.1,0.5))
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# As expected the big club players have more page views than no big club players, big club players are more popular on social media.

# %%
sns.displot(data=df,x='fpl_sel',kind="kde",hue="big_club")
plt.title("Percentage of player selection in FPL")
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',linewidths=5,linecolor="black")
plt.title("Correlation matrix")
plt.show()

# %% [markdown]
# We can see that the strong correlations of market_value are with page_views,fpl_value,fpl_sel,fpl_points and big_club, lets check it individually:

# %%
sns.scatterplot(data=df,x="market_value",y="page_views")
plt.title("market value vs page views")
plt.show()

# %%
sns.scatterplot(data=df,x="market_value",y="fpl_value")
plt.title("market value vs FPL value")
plt.show()

# %%
sns.scatterplot(data=df,x="market_value",y="fpl_sel")
plt.title("market value vs FPL % selection")
plt.show()

# %%
sns.scatterplot(data=df,x="market_value",y="fpl_points")
plt.title("market value vs FPL points")
plt.show()

# %%
sns.scatterplot(data=df,x="market_value",y="big_club")
plt.title("market value vs Big club")
plt.show()

# %%
plt.figure(figsize=(13,7))
sns.heatmap(df[['fpl_value','page_views','fpl_sel','fpl_points']].corr(),annot=True,cmap='coolwarm',linewidths=5,linecolor="black")
plt.title("Correlation matrix")
plt.show()

# %% [markdown]
# We will fit a model for predicting the market value of a player.For this we will use fpl_value and big_club.

# %%
X = df[['fpl_value','big_club']]
y = df['market_value']

# %% [markdown]
# Now we make the train and test split:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
